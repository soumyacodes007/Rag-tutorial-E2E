# %%
1+1
# Out:
# 2

# %%
import langchain

# %%
import os 
from typing import List,Dict,Any

# %%
from langchain_text_splitters import (
    RecursiveCharacterTextSplitter,
    CharacterTextSplitter,
    TokenTextSplitter

)
print ("done")
# Out:
# done

# %%
import os

# Create directory structure
os.makedirs("data/text_files", exist_ok=True)

# Large sample text 1
text1 = """Retrieval-Augmented Generation (RAG) is an advanced AI architecture that combines
information retrieval with natural language generation. Instead of relying solely on a model’s
pre-trained knowledge, RAG systems fetch relevant documents from an external knowledge base
and use them to generate more accurate and context-aware responses.

This approach is particularly useful in domains where information changes frequently, such as
finance, healthcare, or technical documentation. By retrieving up-to-date documents, RAG systems
can provide answers that reflect the latest available knowledge rather than outdated training data.

The typical pipeline of a RAG system involves document ingestion, text chunking, embedding generation,
vector storage, and retrieval at query time. When a user asks a question, the system searches for
relevant chunks using similarity search and feeds them into a language model as context.

RAG is widely used in building chatbots, question-answering systems, and enterprise knowledge assistants.
It significantly improves factual accuracy, reduces hallucinations, and allows customization using private data.
"""

# Large sample text 2
text2 = """Vector databases play a crucial role in modern AI applications, especially in systems like
Retrieval-Augmented Generation. These databases store embeddings, which are numerical representations
of text, images, or other data types, enabling efficient similarity search.

When text is processed through an embedding model, it gets converted into a high-dimensional vector.
These vectors capture semantic meaning, allowing systems to find similar content even if the wording differs.
For example, "How to learn AI?" and "Ways to study artificial intelligence" may have very similar embeddings.

Popular vector databases include FAISS, Pinecone, and Weaviate. They support operations like nearest neighbor
search, filtering, and indexing, making them highly efficient for large-scale applications.

In a typical workflow, documents are first split into chunks, then converted into embeddings, and stored in a
vector database. At query time, the user's input is also embedded, and the system retrieves the most similar
chunks to provide relevant context to the language model.

This architecture enables scalable, fast, and accurate retrieval, forming the backbone of many intelligent systems today.
"""

# Write files
with open("data/text_files/sample1.txt", "w") as f:
    f.write(text1)

with open("data/text_files/sample2.txt", "w") as f:
    f.write(text2)

print("Directory and files created successfully!")
# Out:
# Directory and files created successfully!

# %%
from langchain_community.document_loaders import TextLoader

# %%
loader = TextLoader("data/text_files/sample2.txt")

# %%
docs = loader.load()

# %%
print(docs)
# Out:
# [Document(metadata={'source': 'data/text_files/sample2.txt'}, page_content='Vector databases play a crucial role in modern AI applications, especially in systems like\nRetrieval-Augmented Generation. These databases store embeddings, which are numerical representations\nof text, images, or other data types, enabling efficient similarity search.\n\nWhen text is processed through an embedding model, it gets converted into a high-dimensional vector.\nThese vectors capture semantic meaning, allowing systems to find similar content even if the wording differs.\nFor example, "How to learn AI?" and "Ways to study artificial intelligence" may have very similar embeddings.\n\nPopular vector databases include FAISS, Pinecone, and Weaviate. They support operations like nearest neighbor\nsearch, filtering, and indexing, making them highly efficient for large-scale applications.\n\nIn a typical workflow, documents are first split into chunks, then converted into embeddings, and stored in a\nvecto
# ...

# %%
print(docs[0].metadata)
# Out:
# {'source': 'data/text_files/sample2.txt'}

# %%
print(docs[0].page_content)
# Out:
# Vector databases play a crucial role in modern AI applications, especially in systems like
# Retrieval-Augmented Generation. These databases store embeddings, which are numerical representations
# of text, images, or other data types, enabling efficient similarity search.
#
# When text is processed through an embedding model, it gets converted into a high-dimensional vector.
# These vectors capture semantic meaning, allowing systems to find similar content even if the wording differs.
# For example, "How to learn AI?" and "Ways to study artificial intelligence" may have very similar embeddings.
#
# Popular vector databases include FAISS, Pinecone, and Weaviate. They support operations like nearest neighbor
# search, filtering, and indexing, making them highly efficient for large-scale applications.
#
# In a typical workflow, documents are first split into chunks, then converted into embeddings, and stored in a
# ...

# %%
from langchain_community.document_loaders import DirectoryLoader, TextLoader

# Load all .txt files in the directory using the TextLoader
loader = DirectoryLoader(
    "./data/text_files", 
    glob="**/*.txt", 
    show_progress=True,
    loader_cls=TextLoader
)

docs = loader.load()
# Out:
# 100%|██████████| 2/2 [00:00<00:00, 2358.34it/s]

# %%
print(docs)
# Out:
# [Document(metadata={'source': 'data\\text_files\\sample1.txt'}, page_content='Retrieval-Augmented Generation (RAG) is an advanced AI architecture that combines\ninformation retrieval with natural language generation. Instead of relying solely on a model’s\npre-trained knowledge, RAG systems fetch relevant documents from an external knowledge base\nand use them to generate more accurate and context-aware responses.\n\nThis approach is particularly useful in domains where information changes frequently, such as\nfinance, healthcare, or technical documentation. By retrieving up-to-date documents, RAG systems\ncan provide answers that reflect the latest available knowledge rather than outdated training data.\n\nThe typical pipeline of a RAG system involves document ingestion, text chunking, embedding generation,\nvector storage, and retrieval at query time. When a user asks a question, the system searches for\nrelevant chunks using similarity search and feeds them into a language model a
# ...

# %%
print(docs[1])
# Out:
# page_content='Vector databases play a crucial role in modern AI applications, especially in systems like
# Retrieval-Augmented Generation. These databases store embeddings, which are numerical representations
# of text, images, or other data types, enabling efficient similarity search.
#
# When text is processed through an embedding model, it gets converted into a high-dimensional vector.
# These vectors capture semantic meaning, allowing systems to find similar content even if the wording differs.
# For example, "How to learn AI?" and "Ways to study artificial intelligence" may have very similar embeddings.
#
# Popular vector databases include FAISS, Pinecone, and Weaviate. They support operations like nearest neighbor
# search, filtering, and indexing, making them highly efficient for large-scale applications.
#
# In a typical workflow, documents are first split into chunks, then converted into embeddings, and stored in a
# ...

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

# 1. Assume 'docs' is your list of loaded Document objects
# 2. Initialize the splitter
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=100,
    chunk_overlap=20
)

# 3. Split the documents
split_docs = text_splitter.split_documents(docs)

# 'split_docs' is now a new list of Document objects with smaller content

# %%
print(1)
# Out:
# 1

# %%
print(split_docs[0])
# Out:
# page_content='Retrieval-Augmented Generation (RAG) is an advanced AI architecture that combines' metadata={'source': 'data\\text_files\\sample1.txt'}
